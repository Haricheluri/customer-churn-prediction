# %% [markdown]
# # Phase 5: Feature Engineering and Selection

# %%
import pandas as pd

import pandas as pd

from sklearn.feature_selection import (
    VarianceThreshold,
    mutual_info_classif
)
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv(
    "../data/processed/final_customer_data.csv"
)

df.shape
# Out:
# (150000, 109)

# %%
remove_cols = [

    # leakage
    "predicted_churn_prob",
    "churn_reason",

    # very high target correlation
    "days_since_last_order",
    "support_tickets_30d",
    "nps_score_x",

    # optional
    # "complaint_count",

    # ids
    "customer_id",
    "billing_id",
    "metric_id",

    # personal
    "name",
    "first_name",
    "last_name",
    "email",
    "phone",
    "street_address",
    "postal_code",

    # high cardinality
    "occupation",
    "city",
    "state",
    "billing_address_city",
    "account_manager_x",
    "account_manager_y",

    # duplicate
    "payment_method_y",
    "contract_type_y",
    "tenure_months_y",
    "nps_score_y"
]

df.drop(
    columns=remove_cols,
    inplace=True
)

print(df.shape)
# Out:
# (150000, 84)

# %%
date_cols = [
    "signup_date",
    "last_contact_date",
    "contract_end_date",
    "measured_date",
    "created_at_x",
    "updated_at_x",
    "created_at_y",
    "updated_at_y",
    "last_login_date_x",
    "last_login_date_y"
]

for col in date_cols:

    df[col] = pd.to_datetime(
        df[col],
        errors="coerce"
    )

    df[f"{col}_year"] = df[col].dt.year

    df[f"{col}_month"] = df[col].dt.month

df.drop(
    columns=date_cols,
    inplace=True
)

print(df.shape)
# Out:
# (150000, 94)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 94 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   tenure_months_x            150000 non-null  int64
#  1   contract_type_x            150000 non-null  object
#  2   monthly_spend              150000 non-null  float64
#  3   total_spend                150000 non-null  float64
#  4   order_count                150000 non-null  int64
#  5   avg_order_value            150000 non-null  float64
#  6   payment_method_x           150000 non-null  object
#  7   autopay                    150000 non-null  int64
#  8   num_products_owned         150000 non-null  int64
#  9   complaint_count            150000 non-null  int64
#  10  satisfaction_score         150000 non-null  int64
#  11  churned                    150000 non-null  int64
#  12  retention_offer_sent       150000 non-null  object
#  13  offer_accepted             150000 non-null  int64
#  14  country                    150000 non-null  object
#  15  age                        150000 non-null  float64
#  16  gender                     150000 non-null  object
#  17  marital_status             150000 non-null  object
#  18  household_size             150000 non-null  float64
#  19  segment                    150000 non-null  object
#  20  lifetime_value             150000 non-null  float64
#  21  loyalty_points             150000 non-null  float64
#  22  preferred_channel          150000 non-null  object
#  23  preferred_language         150000 non-null  object
#  24  account_status             150000 non-null  object
#  25  referral_source            150000 non-null  object
#  26  email_opt_in               150000 non-null  float64
#  27  sms_opt_in                 150000 non-null  float64
#  28  plan_name                  150000 non-null  object
#  29  monthly_recurring_revenue  150000 non-null  float64
#  30  annual_contract_value      150000 non-null  float64
#  31  billing_cycle              150000 non-null  object
#  32  autopay_enabled            150000 non-null  float64
#  33  paperless_billing          150000 non-null  float64
#  34  late_payments_12m          150000 non-null  float64
#  35  price_increase_last_year   150000 non-null  float64
#  36  discount_pct               150000 non-null  float64
#  37  payment_failures_90d       150000 non-null  float64
#  38  tax_exempt                 150000 non-null  float64
#  39  invoice_delivery           150000 non-null  object
#  40  login_frequency_30d        150000 non-null  int64
#  41  pages_per_session          150000 non-null  float64
#  42  avg_session_duration_min   150000 non-null  float64
#  43  mobile_app_usage_pct       150000 non-null  float64
#  44  email_open_rate            150000 non-null  float64
#  45  email_click_rate           150000 non-null  float64
#  46  push_notification_opt_in   150000 non-null  int64
#  47  csat_score                 150000 non-null  int64
#  48  feature_adoption_score     150000 non-null  float64
#  49  community_forum_posts      150000 non-null  int64
#  50  referrals_made             150000 non-null  int64
#  51  support_escalations_90d    150000 non-null  int64
#  52  product_tours_completed    150000 non-null  int64
#  53  wishlist_items             150000 non-null  int64
#  54  cart_abandonment_rate      150000 non-null  float64
#  55  promo_code_usage_90d       150000 non-null  int64
#  56  engagement_tier            150000 non-null  object
#  57  recency_days               150000 non-null  float64
#  58  frequency                  150000 non-null  float64
#  59  monetary                   150000 non-null  float64
#  60  r_score                    150000 non-null  float64
#  61  f_score                    150000 non-null  float64
#  62  m_score                    150000 non-null  float64
#  63  total_orders               150000 non-null  float64
#  64  total_revenue              150000 non-null  float64
#  65  total_discount             150000 non-null  float64
#  66  total_shipping_cost        150000 non-null  float64
#  67  gift_orders                150000 non-null  float64
#  68  total_tickets              150000 non-null  float64
#  69  avg_resolution_time        150000 non-null  float64
#  70  total_campaigns            150000 non-null  float64
#  71  responded                  150000 non-null  float64
#  72  converted                  150000 non-null  float64
#  73  campaign_revenue           150000 non-null  float64
#  74  signup_date_year           93551 non-null   float64
#  75  signup_date_month          93551 non-null   float64
#  76  last_contact_date_year     150000 non-null  int32
#  77  last_contact_date_month    150000 non-null  int32
#  78  contract_end_date_year     126941 non-null  float64
#  79  contract_end_date_month    126941 non-null  float64
#  80  measured_date_year         150000 non-null  int32
#  81  measured_date_month        150000 non-null  int32
#  82  created_at_x_year          93551 non-null   float64
#  83  created_at_x_month         93551 non-null   float64
#  84  updated_at_x_year          150000 non-null  int32
#  85  updated_at_x_month         150000 non-null  int32
#  86  created_at_y_year          126941 non-null  float64
#  87  created_at_y_month         126941 non-null  float64
#  88  updated_at_y_year          126941 non-null  float64
#  89  updated_at_y_month         126941 non-null  float64
#  90  last_login_date_x_year     93551 non-null   float64
#  91  last_login_date_x_month    93551 non-null   float64
#  92  last_login_date_y_year     150000 non-null  int32
#  93  last_login_date_y_month    150000 non-null  int32
# dtypes: float64(54), int32(8), int64(17), object(15)
# memory usage: 103.0+ MB

# %%
df.to_csv(
    "../data/processed/final_features.csv",
    index=False
)

# %%
pd.read_csv(
    "../data/processed/final_features.csv"
).shape
# Out:
# (150000, 94)
